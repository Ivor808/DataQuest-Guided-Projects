# %% [markdown]
# ## Introduction

# %%
import pandas as pd
import matplotlib
# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')
print(recent_grads.iloc[0])
print('--')
recent_grads.describe()
recent_grads = recent_grads.dropna()
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# Low_wage_jobs                             193
# Name: 0, dtype: object
# --

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# ### Sample Size and Median

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter')

# %% [markdown]
# ### Sample Size and Unemployment Rate

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')

# %% [markdown]
# ### Full Time and Median

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter')

# %% [markdown]
# ### ShareWomen and Unemployment Rate

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')

# %% [markdown]
# ### Men and Median

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter')

# %% [markdown]
# ### Women and Median

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter')

# %% [markdown]
# ## Histogram

# %% [markdown]
# ### Sample Size

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,5000))

# %% [markdown]
# ### Median

# %%
recent_grads['Median'].hist(bins=10)

# %% [markdown]
# ### Employed

# %%
recent_grads['Employed'].hist(bins=20,range=(100,350000))

# %% [markdown]
# ### Full time

# %%
recent_grads['Full_time'].hist(bins=10)

# %% [markdown]
# ### ShareWomen

# %%
recent_grads['ShareWomen'].hist(bins=15)

# %% [markdown]
# ### Unemployment Rate

# %%
recent_grads['Unemployment_rate'].hist(bins=20,range=(0,0.15))

# %% [markdown]
# ### Men

# %%
recent_grads['Men'].hist(bins=10)

# %% [markdown]
# ### Women

# %%
recent_grads['Women'].hist(bins=10)

# %% [markdown]
# ## Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size','Median']],figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7faf76c3e3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf76b92cf8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7faf76b2b7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf76b1d080>]],
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']],figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7faf76a434a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf769b5160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf7697da90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7faf76939710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf76901a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf768be5f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7faf76886710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf76896940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf768146d8>]],
#       dtype=object)

# %% [markdown]
# ## Bar Plots

# %%
recent_grads[:10].plot.bar(x='Major',y='ShareWomen',legend=False)

# %%
recent_grads[163:].plot.bar(x='Major',y='ShareWomen',legend=False)

# %%
recent_grads[:10].plot.bar(x='Major',y='Unemployment_rate',legend=False)

# %%
recent_grads[163:].plot.bar(x='Major',y='Unemployment_rate',legend=False)
